# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import cv2

from sklearn.model_selection import KFold, cross_val_score


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier, IsolationForest

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC

from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_objective, plot_histogram


from sklearn.pipeline import Pipeline

from src.utils.feats import load_gei
from src.utils.results import df_results


import pandas as pd

# %%
# Kfold
n_splits = 3
cv = KFold(n_splits=n_splits, random_state=42, shuffle=True)
    
# classifier
model = RandomForestClassifier(n_estimators=150, max_depth=None, random_state=0, criterion='gini')

# %%
datapath = "../data/feats/database24_gei_480x640.pkl"

dim = (64, 48)

crop_person = True

X, y = load_gei(datapath, dim=dim, crop_person=crop_person)

# %%
# pipeline class is used as estimator to enable
# search over different model types

pipe = Pipeline([
    ('model', KNeighborsClassifier())
])

# %%
# single categorical value of 'model' parameter is
# sets the model class
# We will get ConvergenceWarnings because the problem is not well-conditioned.
# But that's fine, this is just an example.



# from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
# from sklearn.ensemble import RandomForestClassifier, IsolationForest

# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import LinearSVC, SVC

# explicit dimension classes can be specified like this

ada_search = {
    'model': Categorical([AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=10), random_state=0)]),    
    'model__n_estimators': Integer(300, 1100),     
    'model__learning_rate': Real(0.1, 0.5, prior='uniform'),
}

# gdb_search = {
#     'model': Categorical([GradientBoostingClassifier(max_depth=None, random_state=0)]),    
#     'model__learning_rate': Real(1e-3, 0.5, prior='uniform'),
#     'model__n_estimators': Integer(1, 400),         
#     'model__max_depth': Integer(1, 400),     
# }


knn_search = {
    'model': Categorical([KNeighborsClassifier()]),    
    'model__n_neighbors': Integer(1,6),    
}

rf_search = {
    'model': Categorical([RandomForestClassifier(max_depth=None, random_state=0, criterion='gini')]),    
    'model__n_estimators': Integer(250, 400),    
}

svc_search = {
    'model': Categorical([SVC()]),
    'model__C': Real(1e-6, 1e+6, prior='log-uniform'),
    'model__gamma': Real(1e-6, 1e+1, prior='log-uniform'),
    'model__degree': Integer(1,8),
    'model__kernel': Categorical(['linear', 'poly', 'rbf']),
}

# %%
opt = BayesSearchCV(
    pipe,
    # (parameter space, # of evaluations)    
    [(ada_search, 32), (knn_search, 8), (svc_search, 128), (rf_search, 128)],
    cv=cv,
    scoring='accuracy'
)

opt.fit(X, y)

# %%
df = df_results(opt)
df.to_csv('results_classifiers_bayes_search.csv')
df
# Out:
#                                                  model  model__learning_rate  \
# 87   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 51   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 68   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 148  SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 98   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# ..                                                 ...                   ...
# 47   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 54   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 59   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 73   SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
# 127  SVC(C=1000000.0, degree=1, gamma=3.26500109005...                   NaN
#
#      model__n_estimators  model__n_neighbors        model__C  model__degree  \
# 87                   NaN                 NaN  1000000.000000            1.0
# 51                   NaN                 NaN  1000000.000000            1.0
# 68                   NaN                 NaN  1000000.000000            8.0
# 148                  NaN                 NaN       31.373243            1.0
# 98                   NaN                 NaN       72.561062            1.0
# ..                   ...                 ...             ...            ...
# 47                   NaN                 NaN      417.510639            2.0
# 54                   NaN                 NaN        0.000001            1.0
# 59                   NaN                 NaN        0.000001            1.0
# 73                   NaN                 NaN        0.005878            8.0
# 127                  NaN                 NaN  1000000.000000            8.0
#
#      model__gamma model__kernel  mean_test_score  std_test_score  rank
# 87       0.000001           rbf         0.864717        0.002932     1
# 51       0.000033           rbf         0.864717        0.002932     1
# 68       0.000001           rbf         0.864717        0.002932     1
# 148     10.000000          poly         0.862888        0.004786     4
# 98       1.517500          poly         0.862888        0.004786     4
# ..            ...           ...              ...             ...   ...
# 47       0.181862           rbf         0.038391        0.009038   291
# 54       0.000047        linear         0.038391        0.009038   291
# 59       5.512171          poly         0.038391        0.009038   291
# 73      10.000000           rbf         0.038391        0.009038   291
# 127     10.000000           rbf         0.038391        0.009038   291
#
# [296 rows x 11 columns]

# %%
# 5 best ADA models
df[df['model__learning_rate']>0].head(5)
# Out:
#                                                 model  model__learning_rate  \
# 21  AdaBoostClassifier(base_estimator=DecisionTree...              0.273532
# 16  AdaBoostClassifier(base_estimator=DecisionTree...              0.314346
# 31  AdaBoostClassifier(base_estimator=DecisionTree...              0.287706
# 27  AdaBoostClassifier(base_estimator=DecisionTree...              0.364809
# 19  AdaBoostClassifier(base_estimator=DecisionTree...              0.298465
#
#     model__n_estimators  model__n_neighbors  model__C  model__degree  \
# 21                721.0                 NaN       NaN            NaN
# 16                703.0                 NaN       NaN            NaN
# 31                732.0                 NaN       NaN            NaN
# 27               1100.0                 NaN       NaN            NaN
# 19                681.0                 NaN       NaN            NaN
#
#     model__gamma model__kernel  mean_test_score  std_test_score  rank
# 21           NaN           NaN         0.835466        0.007324   219
# 16           NaN           NaN         0.831810        0.015366   231
# 31           NaN           NaN         0.826325        0.031918   245
# 27           NaN           NaN         0.826325        0.004717   245
# 19           NaN           NaN         0.826325        0.016494   245

# %%
# 5 best knn models
df[df['model__n_neighbors']>0].head(5)
# Out:
#                      model  model__learning_rate  model__n_estimators  \
# 36  KNeighborsClassifier()                   NaN                  NaN
# 32  KNeighborsClassifier()                   NaN                  NaN
# 34  KNeighborsClassifier()                   NaN                  NaN
# 39  KNeighborsClassifier()                   NaN                  NaN
# 33  KNeighborsClassifier()                   NaN                  NaN
#
#     model__n_neighbors  model__C  model__degree  model__gamma model__kernel  \
# 36                 2.0       NaN            NaN           NaN           NaN
# 32                 5.0       NaN            NaN           NaN           NaN
# 34                 5.0       NaN            NaN           NaN           NaN
# 39                 6.0       NaN            NaN           NaN           NaN
# 33                 3.0       NaN            NaN           NaN           NaN
#
#     mean_test_score  std_test_score  rank
# 36         0.685558        0.025417   280
# 32         0.681901        0.014677   281
# 34         0.681901        0.014677   281
# 39         0.676417        0.004559   283
# 33         0.661792        0.032126   284

# %%
# 5 best RF models
df[df['model__n_estimators']>0].head(5)
# Out:
#                                       model  model__learning_rate  \
# 273  RandomForestClassifier(random_state=0)                   NaN
# 275  RandomForestClassifier(random_state=0)                   NaN
# 276  RandomForestClassifier(random_state=0)                   NaN
# 279  RandomForestClassifier(random_state=0)                   NaN
# 281  RandomForestClassifier(random_state=0)                   NaN
#
#      model__n_estimators  model__n_neighbors  model__C  model__degree  \
# 273                358.0                 NaN       NaN            NaN
# 275                358.0                 NaN       NaN            NaN
# 276                358.0                 NaN       NaN            NaN
# 279                358.0                 NaN       NaN            NaN
# 281                358.0                 NaN       NaN            NaN
#
#      model__gamma model__kernel  mean_test_score  std_test_score  rank
# 273           NaN           NaN         0.846435        0.019378   116
# 275           NaN           NaN         0.846435        0.019378   116
# 276           NaN           NaN         0.846435        0.019378   116
# 279           NaN           NaN         0.846435        0.019378   116
# 281           NaN           NaN         0.846435        0.019378   116

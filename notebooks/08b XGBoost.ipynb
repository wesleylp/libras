# %%
from xgboost import XGBClassifier

# %%
from src.utils.feats import load_gei
from sklearn.model_selection import KFold, cross_val_score
from src.utils.feats import load_gei

from sklearn.pipeline import Pipeline

from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_objective, plot_histogram

from src.utils.results import df_results
import pandas as pd

# %%
datapath = "../data/feats/database24_gei_480x640.pkl"

dim = (64, 48)

crop_person = True

X, y = load_gei(datapath, dim=dim, crop_person=crop_person)

# %%
# Kfold
n_splits = 3
cv = KFold(n_splits=n_splits, random_state=42, shuffle=True)

# %%
res = cross_val_score(XGBClassifier(
    objective='multi:softmax',
    eval_metric='merror',
    use_label_encoder=False,
    random_state=0,
    learning_rate=1e-2,
    n_estimators=1000,
    max_depth=3, 
    subsample=0.8,
    colsample_bytree=1,
    gamma=1
), X, y, cv=cv)

# %%
print(f"Mean acc: {res.mean():.5f} +/- {res.std():.5f}")
# Out:
# Mean acc: 0.69298 +/- 0.04641

# %%
# pipeline class is used as estimator to enable
# search over different model types

pipe = Pipeline([
    ('model', XGBClassifier())
])

# %%
# explicit dimension classes can be specified like this

xgb_search = {
    'model': Categorical([XGBClassifier(
        objective='multi:softmax',
        eval_metric='merror',
        use_label_encoder=False,
        random_state=0)]),    
    'model__n_estimators': Integer(600, 1200, prior='log-uniform'),     
    'model__learning_rate': Real(0.09, 0.15, prior='uniform'),
    'model__booster': Categorical(['dart']), # 'dart' presented best results. 
#     Rashmi et al. DART: Dropouts meet Multiple Additive Regression Trees 
#     18th International Conference on Artificial Intelligence and Statistics (AISTATS) 2015, San Diego.
    'model__min_child_leaf': Integer(50, 150),
    'model__max_depth': Integer(5, 12),
    'model__gamma': Real(1e-8, 1e-3, prior='uniform'),
    'model__subsample': Real(0.3, 0.8, prior='uniform'),
    'model__colsample_bytree': Real(0.3, 0.8, prior='uniform'),
}

opt = BayesSearchCV(
    pipe,
    # (parameter space, # of evaluations)    
    [(xgb_search, 256)],
    cv=cv,
    scoring='accuracy'
)

# %%
opt.fit(X, y)
# Out:
# [12:00:35] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:03:38] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:06:48] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:09:48] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:12:27] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:15:43] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:18:52] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:21:26] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:24:00] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:26:34] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:28:40] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:30:40] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:32:45] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:35:35] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:50] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:33] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:43:44] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:45:52] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:56] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:44] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:39] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:31] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:06] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:00:29] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:49] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:05:48] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:07:49] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:09:59] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:13:00] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:15:51] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:18:32] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:21:04] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:23:32] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:25:57] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:29:26] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:33:02] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:37:16] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:40:58] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:44:52] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:48:54] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:51:43] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:37] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:34] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:53] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:05:54] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:09:38] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:22] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:14:46] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:17:17] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:20:35] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [14:24:07] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:28:06] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:32:47] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:37:17] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:42:00] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:44:26] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:46:48] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:49:20] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:51:55] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:54:27] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:56:57] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:00:45] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:04:25] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:08:02] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:11:58] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:16:01] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:20:16] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:21:49] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:23:21] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:24:50] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:28:12] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:31:28] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:34:25] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:36:31] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:38:45] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [15:41:11] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:43:33] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:45:53] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:48:13] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:52:22] WARNING: ../src/learner.cc:541:
# Parameters: { min_child_leaf } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
df = df_results(opt)
df.to_csv('results_XGBoost.csv')
df[:20]
# Out:
#                                                  model model__booster  \
# 254  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 201  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 54   XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 226  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 88   XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 106  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 105  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 205  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 100  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 212  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 224  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 52   XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 223  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 221  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 109  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 219  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 148  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 66   XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 215  XGBClassifier(base_score=0.5, booster='dart', ...           dart
# 95   XGBClassifier(base_score=0.5, booster='dart', ...           dart
#
#      model__colsample_bytree  model__gamma  model__learning_rate  \
# 254                 0.375165  1.000000e-08              0.099129
# 201                 0.412522  1.000000e-08              0.129058
# 54                  0.359399  1.000000e-08              0.136385
# 226                 0.300000  1.893770e-04              0.097761
# 88                  0.300000  1.000000e-08              0.090000
# 106                 0.300000  1.000000e-08              0.090000
# 105                 0.300000  1.000000e-08              0.090000
# 205                 0.300000  1.000000e-08              0.090000
# 100                 0.300000  1.000000e-08              0.090000
# 212                 0.300000  1.000000e-08              0.090000
# 224                 0.300000  1.000000e-08              0.090000
# 52                  0.300000  1.000000e-08              0.090000
# 223                 0.300000  1.000000e-08              0.090000
# 221                 0.300000  1.000000e-08              0.090000
# 109                 0.300000  1.000000e-08              0.090000
# 219                 0.300000  1.000000e-08              0.090000
# 148                 0.300000  1.000000e-08              0.090000
# 66                  0.304598  5.146383e-05              0.132541
# 215                 0.346590  1.000000e-08              0.144568
# 95                  0.300000  1.000000e-08              0.090000
#
#      model__max_depth  model__min_child_leaf  model__n_estimators  \
# 254                 5                     66                  695
# 201                 5                     50                 1200
# 54                  5                    143                  726
# 226                 5                    123                 1088
# 88                 12                     50                 1200
# 106                12                    150                 1200
# 105                12                     50                 1200
# 205                12                     50                 1200
# 100                 5                    150                 1200
# 212                12                     50                 1200
# 224                12                     50                 1200
# 52                  5                     99                  959
# 223                 7                     50                  944
# 221                12                     50                 1200
# 109                12                    150                 1200
# 219                 5                     50                 1200
# 148                 5                    150                 1200
# 66                  6                    118                 1179
# 215                 5                    143                  717
# 95                 12                     50                 1200
#
#      model__subsample  mean_test_score  std_test_score  rank
# 254          0.327273         0.793419        0.015286     1
# 201          0.300000         0.791590        0.012965     2
# 54           0.300000         0.787934        0.024197     3
# 226          0.315144         0.787934        0.028665     3
# 88           0.300000         0.786106        0.026664     5
# 106          0.300000         0.786106        0.026664     5
# 105          0.300000         0.786106        0.026664     5
# 205          0.300000         0.786106        0.026664     5
# 100          0.300000         0.786106        0.026664     5
# 212          0.300000         0.786106        0.026664     5
# 224          0.300000         0.786106        0.026664     5
# 52           0.300000         0.786106        0.026664     5
# 223          0.300000         0.786106        0.026664     5
# 221          0.300000         0.786106        0.026664     5
# 109          0.300000         0.786106        0.026664     5
# 219          0.300000         0.786106        0.026664     5
# 148          0.300000         0.786106        0.026664     5
# 66           0.304517         0.786106        0.024401     5
# 215          0.300000         0.786106        0.031015     5
# 95           0.300000         0.786106        0.026664     5
